# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
# Loading Normalized log-scaled standard-deviation sorted dataframe
df = pd.read_csv('assignment4_dataset.csv', index_col=0)

# %%
df
# Out:
#                                CD4      CD8A  KLRC4-KLRK1      CD8B    STXBP2  \
# refinebio_accession_code
# SRR7725764                8.164929  0.000000     0.000000  2.165702  0.000000
# SRR7725765                8.328641  2.373090     3.572271  2.013168  0.000000
# SRR7725767                0.000000  7.783076     6.575891  7.922238  7.388587
# SRR7725768                0.000000  8.555245     7.407132  6.659247  0.000000
# SRR7725770                1.150113  8.135226     6.840089  8.626322  0.000000
# ...                            ...       ...          ...       ...       ...
# SRR7726017                7.544641  0.000000     0.000000  2.802657  6.284985
# SRR7726018                0.000000  7.209779     8.373188  8.040202  6.365506
# SRR7726019                0.000000  7.250339     8.480368  8.137742  0.000000
# SRR7726020                0.000000  7.538558     8.621674  7.936845  7.166590
# SRR7726021                1.211576  7.331144     8.664808  8.607863  6.416606
#
# ...

# %%
df_10 = df.iloc[:, :10]
df_100 = df.iloc[:, :100]
df_1000 = df.iloc[:, :1000]
df_5000 = df.iloc[:, :5000]
df_10000 = df.iloc[:, :10000]

# %%
labels = df['Group']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_10000, labels, test_size=0.33, random_state=69)

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
y_pred = clf.predict(X_test)

# %%
y_pred_prob = clf.predict_proba(X_test)

# %%
y_pred_prob
# Out:
# array([[0.63920855, 0.36079145],
#        [0.66490383, 0.33509617],
#        [0.35860211, 0.64139789],
#        [0.47554369, 0.52445631],
#        [0.45414997, 0.54585003],
#        [0.68309144, 0.31690856],
#        [0.39522687, 0.60477313],
#        [0.44708068, 0.55291932],
#        [0.43911065, 0.56088935],
#        [0.5178652 , 0.4821348 ],
#        [0.44877313, 0.55122687],
#        [0.51884954, 0.48115046],
#        [0.67235155, 0.32764845],
#        [0.46941346, 0.53058654],
#        [0.43440168, 0.56559832],
#        [0.41286427, 0.58713573],
#        [0.39944684, 0.60055316],
#        [0.45009158, 0.54990842],
#        [0.49722742, 0.50277258],
#        [0.57712042, 0.42287958],
#        [0.58406886, 0.41593114],
#        [0.592601  , 0.407399  ],
#        [0.47858593, 0.52141407],
#        [0.3810609 , 0.6189391 ],
#        [0.48023692, 0.51976308],
#        [0.48485058, 0.51514942],
#        [0.37928381, 0.62071619],
#        [0.58227539, 0.41772461],
# ...

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 1], pos_label='ra non treatment')

# %%
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob[:, 1])

# %%
roc_auc
# Out:
# 0.7323232323232323

# %%
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[11, 11],
#        [ 4, 14]], dtype=int64)

# %% [markdown]
# # Testing For Different Numbers of Genes

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :10], y_train)
y_pred = clf.predict(X_test.iloc[:, :10])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :10])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 1], pos_label='ra non treatment')
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 9, 13],
#        [ 8, 10]], dtype=int64)

# %%
metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
# Out:
# 0.4090909090909091

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :100], y_train)
y_pred = clf.predict(X_test.iloc[:, :100])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :100])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 1], pos_label='ra non treatment')
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[11, 11],
#        [ 7, 11]], dtype=int64)

# %%
metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
# Out:
# 0.5732323232323232

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :1000], y_train)
y_pred = clf.predict(X_test.iloc[:, :1000])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :1000])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 1], pos_label='ra non treatment')
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[12, 10],
#        [ 6, 12]], dtype=int64)

# %%
metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
# Out:
# 0.6262626262626263

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :5000], y_train)
y_pred = clf.predict(X_test.iloc[:, :5000])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :5000])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 1], pos_label='ra non treatment')
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[15,  7],
#        [ 8, 10]], dtype=int64)

# %%
metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
# Out:
# 0.7348484848484849

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :10000], y_train)
y_pred = clf.predict(X_test.iloc[:, :10000])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :10000])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 1], pos_label='ra non treatment')
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[11, 11],
#        [ 4, 14]], dtype=int64)

# %%
metrics.roc_auc_score(y_test, y_pred_prob[:, 1])
# Out:
# 0.7323232323232323

# %% [markdown]
# # Performance on Clusters

# %%
cluster_labels = df['Agglomerative Cluster']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_10000, cluster_labels, test_size=0.33, random_state=69)

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 0], pos_label=0)
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob, multi_class = 'ovr')
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
roc_auc
# Out:
# 0.9901190476190476

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :10], y_train)
y_pred = clf.predict(X_test.iloc[:, :10])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :10])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 0], pos_label=0)
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob, multi_class = 'ovr')
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
roc_auc
# Out:
# 0.9663999999999999

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :100], y_train)
y_pred = clf.predict(X_test.iloc[:, :100])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :100])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 0], pos_label=0)
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob, multi_class = 'ovr')
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
roc_auc
# Out:
# 0.9803904761904763

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :1000], y_train)
y_pred = clf.predict(X_test.iloc[:, :1000])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :1000])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 0], pos_label=0)
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob, multi_class = 'ovr')
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
roc_auc
# Out:
# 0.9901190476190476

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train.iloc[:, :5000], y_train)
y_pred = clf.predict(X_test.iloc[:, :5000])
y_pred_prob = clf.predict_proba(X_test.iloc[:, :5000])
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob[:, 0], pos_label=0)
roc_auc = metrics.roc_auc_score(y_test, y_pred_prob, multi_class = 'ovr')
plt.plot(fpr, tpr, label='ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
roc_auc
# Out:
# 0.9892984126984127

# %% [markdown]
# # Compilation Of All Algorithms

# %%
df
# Out:
#                                CD4      CD8A  KLRC4-KLRK1      CD8B    STXBP2  \
# refinebio_accession_code
# SRR7725764                8.164929  0.000000     0.000000  2.165702  0.000000
# SRR7725765                8.328641  2.373090     3.572271  2.013168  0.000000
# SRR7725767                0.000000  7.783076     6.575891  7.922238  7.388587
# SRR7725768                0.000000  8.555245     7.407132  6.659247  0.000000
# SRR7725770                1.150113  8.135226     6.840089  8.626322  0.000000
# ...                            ...       ...          ...       ...       ...
# SRR7726017                7.544641  0.000000     0.000000  2.802657  6.284985
# SRR7726018                0.000000  7.209779     8.373188  8.040202  6.365506
# SRR7726019                0.000000  7.250339     8.480368  8.137742  0.000000
# SRR7726020                0.000000  7.538558     8.621674  7.936845  7.166590
# SRR7726021                1.211576  7.331144     8.664808  8.607863  6.416606
#
# ...

# %%
df['Spectral Cluster']
# Out:
# refinebio_accession_code
# SRR7725764    0
# SRR7725765    0
# SRR7725767    0
# SRR7725768    0
# SRR7725770    1
#              ..
# SRR7726017    1
# SRR7726018    0
# SRR7726019    0
# SRR7726020    0
# SRR7726021    1
# Name: Spectral Cluster, Length: 119, dtype: int64

# %%
labels = df.iloc[:, -6:]

# %%
labels
# Out:
#                                      Group  Agglomerative Cluster  \
# refinebio_accession_code
# SRR7725764                         healthy                      3
# SRR7725765                         healthy                      0
# SRR7725767                         healthy                      3
# SRR7725768                         healthy                      0
# SRR7725770                         healthy                      2
# ...                                    ...                    ...
# SRR7726017                ra non treatment                      2
# SRR7726018                ra non treatment                      0
# SRR7726019                ra non treatment                      4
# SRR7726020                ra non treatment                      4
# SRR7726021                ra non treatment                      2
#
#                           GMM Cluster  Spectral Cluster  KMedoids Cluster  \
# refinebio_accession_code
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df_5000, labels, test_size=0.33, random_state=69)

# %%
y_train
# Out:
#                                      Group  Agglomerative Cluster  \
# refinebio_accession_code
# SRR7725979                ra non treatment                      3
# SRR7725765                         healthy                      0
# SRR7725984                ra non treatment                      2
# SRR7725981                ra non treatment                      3
# SRR7725965                ra non treatment                      0
# ...                                    ...                    ...
# SRR7725989                ra non treatment                      0
# SRR7726008                ra non treatment                      0
# SRR7725970                ra non treatment                      2
# SRR7725972                ra non treatment                      0
# SRR7725824                         healthy                      4
#
#                           GMM Cluster  Spectral Cluster  KMedoids Cluster  \
# refinebio_accession_code
# ...

# %%
X_train
# Out:
#                                CD4      CD8A  KLRC4-KLRK1      CD8B    STXBP2  \
# refinebio_accession_code
# SRR7725979                8.460067  2.046403     0.000000  0.000000  7.232607
# SRR7725765                8.328641  2.373090     3.572271  2.013168  0.000000
# SRR7725984                8.071684  1.179086     0.000000  2.303145  6.041471
# SRR7725981                0.000000  8.214739     7.899867  7.522723  0.000000
# SRR7725965                8.011578  1.812298     3.912999  0.549319  6.751485
# ...                            ...       ...          ...       ...       ...
# SRR7725989                8.060796  0.528725     0.000000  1.644923  0.000000
# SRR7726008                7.860188  1.839179     0.000000  3.175103  6.624406
# SRR7725970                0.599898  7.827200     7.795231  8.005624  6.314485
# SRR7725972                8.166994  0.000000     2.463943  0.000000  6.595879
# SRR7725824                0.000000  8.587240     8.202103  7.380974  0.000000
#
# ...

# %%
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train['Group'])
rf_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Group'], y_pred_prob[:, 1])
print(roc_auc)

clf = svm.SVC(kernel='linear', probability=True, random_state=20)
clf.fit(X_train, y_train['Group'])
svm_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Group'], y_pred_prob[:, 1])
print(roc_auc)

nb = GaussianNB()
nb.fit(X_train, y_train['Group'])
nb_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Group'],y_pred_prob[:, 1])
print(roc_auc)

knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train['Group'])
knn_pred = knn.predict(X_test)
y_pred_prob = knn.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Group'], y_pred_prob[:, 1])
print(roc_auc)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train['Group'])
lr_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Group'], y_pred_prob[:, 1])
print(roc_auc)
# Out:
# 0.7348484848484849
# 0.9823232323232323
# 0.6262626262626263
# 0.6654040404040404
# 0.9646464646464646

# %%
model_matrix_group = pd.DataFrame({'Actual': y_test['Group'],
                            'Random Forest': rf_pred, 'Support Vector Machine': svm_pred,
                             'Naive Bayes': nb_pred, 'K-Nearest Neighbors': knn_pred,
                             'Logistic Regression': lr_pred})

# %%
# Out:
# Actual
# Random Forest
# Support Vector Machine
# Naive Bayes
# K-Nearest Neighbors
# Logistic Regression

# %%
counts = []
for row_name in model_matrix_group.index:
    row = model_matrix_group.loc[row_name]
    counter = 0
    if row['Actual'] == row['Random Forest']:
        counter += 1
    if row['Actual'] == row['Support Vector Machine']:
        counter += 1
    if row['Actual'] == row['Naive Bayes']:
        counter += 1
    if row['Actual'] == row['K-Nearest Neighbors']:
        counter += 1
    if row['Actual'] == row['Logistic Regression']:
        counter += 1
    counts.append(counter)
model_matrix_group['Number Correct'] = counts

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train['Agglomerative Cluster'])
rf_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Agglomerative Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

clf = svm.SVC(kernel='linear', probability=True, random_state=20)
clf.fit(X_train, y_train['Agglomerative Cluster'])
svm_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Agglomerative Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

nb = GaussianNB()
nb.fit(X_train, y_train['Agglomerative Cluster'])
nb_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Agglomerative Cluster'], y_pred_prob, multi_class = 'ovr')
print(roc_auc)

knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train['Agglomerative Cluster'])
knn_pred = knn.predict(X_test)
y_pred_prob = knn.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Agglomerative Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train['Agglomerative Cluster'])
lr_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Agglomerative Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

model_matrix_a = pd.DataFrame({'Actual': y_test['Agglomerative Cluster'],
                            'Random Forest': rf_pred, 'Support Vector Machine': svm_pred,
                             'Naive Bayes': nb_pred, 'K-Nearest Neighbors': knn_pred,
                             'Logistic Regression': lr_pred})

counts = []
for row_name in model_matrix_a.index:
    row = model_matrix_a.loc[row_name]
    counter = 0
    if row['Actual'] == row['Random Forest']:
        counter += 1
    if row['Actual'] == row['Support Vector Machine']:
        counter += 1
    if row['Actual'] == row['Naive Bayes']:
        counter += 1
    if row['Actual'] == row['K-Nearest Neighbors']:
        counter += 1
    if row['Actual'] == row['Logistic Regression']:
        counter += 1
    counts.append(counter)
model_matrix_a['Number Correct'] = counts
model_matrix_a
# Out:
# 0.9892984126984127
# 0.9986111111111111
# 0.7135555555555556
# 0.9888063492063492
# 1.0
#                           Actual  Random Forest  Support Vector Machine  \
# refinebio_accession_code
# SRR7725775                     4              4                       4
# SRR7725785                     0              0                       0
# SRR7725983                     0              0                       0
# SRR7725993                     4              0                       0
# SRR7726021                     2              2                       2
# SRR7725801                     0              0                       0
# SRR7725828                     2              2                       2
# SRR7726007                     2              2                       2
# SRR7725783                     2              2                       2
# SRR7726014                     2              2                       2
# ...

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train['Spectral Cluster'])
rf_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Spectral Cluster'],  y_pred_prob[:, 1])
print(roc_auc)

clf = svm.SVC(kernel='linear', probability=True, random_state=20)
clf.fit(X_train, y_train['Spectral Cluster'])
svm_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Spectral Cluster'],  y_pred_prob[:, 1])
print(roc_auc)

nb = GaussianNB()
nb.fit(X_train, y_train['Spectral Cluster'])
nb_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Spectral Cluster'], y_pred_prob[:, 1])
print(roc_auc)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train['Spectral Cluster'])
knn_pred = knn.predict(X_test)
y_pred_prob = knn.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Spectral Cluster'],  y_pred_prob[:, 1])
print(roc_auc)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train['Spectral Cluster'])
lr_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['Spectral Cluster'],  y_pred_prob[:, 1])
print(roc_auc)

model_matrix_s = pd.DataFrame({'Actual': y_test['Spectral Cluster'],
                            'Random Forest': rf_pred, 'Support Vector Machine': svm_pred,
                             'Naive Bayes': nb_pred, 'K-Nearest Neighbors': knn_pred,
                             'Logistic Regression': lr_pred})

counts = []
for row_name in model_matrix_s.index:
    row = model_matrix_s.loc[row_name]
    counter = 0
    if row['Actual'] == row['Random Forest']:
        counter += 1
    if row['Actual'] == row['Support Vector Machine']:
        counter += 1
    if row['Actual'] == row['Naive Bayes']:
        counter += 1
    if row['Actual'] == row['K-Nearest Neighbors']:
        counter += 1
    if row['Actual'] == row['Logistic Regression']:
        counter += 1
    counts.append(counter)
model_matrix_s['Number Correct'] = counts
# Out:
# 1.0
# 1.0
# 0.5
# 1.0
# 1.0

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train['GMM Cluster'])
rf_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['GMM Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

clf = svm.SVC(kernel='linear', probability=True, random_state=20)
clf.fit(X_train, y_train['GMM Cluster'])
svm_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['GMM Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

nb = GaussianNB()
nb.fit(X_train, y_train['GMM Cluster'])
nb_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['GMM Cluster'], y_pred_prob, multi_class = 'ovr')
print(roc_auc)

knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train['GMM Cluster'])
knn_pred = knn.predict(X_test)
y_pred_prob = knn.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['GMM Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train['GMM Cluster'])
lr_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['GMM Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

model_matrix_g = pd.DataFrame({'Actual': y_test['GMM Cluster'],
                            'Random Forest': rf_pred, 'Support Vector Machine': svm_pred,
                             'Naive Bayes': nb_pred, 'K-Nearest Neighbors': knn_pred,
                             'Logistic Regression': lr_pred})

counts = []
for row_name in model_matrix_g.index:
    row = model_matrix_g.loc[row_name]
    counter = 0
    if row['Actual'] == row['Random Forest']:
        counter += 1
    if row['Actual'] == row['Support Vector Machine']:
        counter += 1
    if row['Actual'] == row['Naive Bayes']:
        counter += 1
    if row['Actual'] == row['K-Nearest Neighbors']:
        counter += 1
    if row['Actual'] == row['Logistic Regression']:
        counter += 1
    counts.append(counter)
model_matrix_g['Number Correct'] = counts
model_matrix_g
# Out:
# 1.0
# 1.0
# 0.8185139933166249
# 1.0
# 1.0
#                           Actual  Random Forest  Support Vector Machine  \
# refinebio_accession_code
# SRR7725775                     2              2                       2
# SRR7725785                     2              2                       2
# SRR7725983                     1              1                       1
# SRR7725993                     2              2                       2
# SRR7726021                     1              1                       1
# SRR7725801                     2              2                       2
# SRR7725828                     1              1                       1
# SRR7726007                     1              1                       1
# SRR7725783                     1              1                       1
# SRR7726014                     1              1                       1
# SRR7725777                     1              1                       1
# ...

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train['KMedoids Cluster'])
rf_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMedoids Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

clf = svm.SVC(kernel='linear', probability=True, random_state=20)
clf.fit(X_train, y_train['KMedoids Cluster'])
svm_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMedoids Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

nb = GaussianNB()
nb.fit(X_train, y_train['KMedoids Cluster'])
nb_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMedoids Cluster'], y_pred_prob, multi_class = 'ovr')
print(roc_auc)

knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train['KMedoids Cluster'])
knn_pred = knn.predict(X_test)
y_pred_prob = knn.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMedoids Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train['KMedoids Cluster'])
lr_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMedoids Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

model_matrix_p = pd.DataFrame({'Actual': y_test['KMedoids Cluster'],
                            'Random Forest': rf_pred, 'Support Vector Machine': svm_pred,
                             'Naive Bayes': nb_pred, 'K-Nearest Neighbors': knn_pred,
                             'Logistic Regression': lr_pred})

counts = []
for row_name in model_matrix_p.index:
    row = model_matrix_p.loc[row_name]
    counter = 0
    if row['Actual'] == row['Random Forest']:
        counter += 1
    if row['Actual'] == row['Support Vector Machine']:
        counter += 1
    if row['Actual'] == row['Naive Bayes']:
        counter += 1
    if row['Actual'] == row['K-Nearest Neighbors']:
        counter += 1
    if row['Actual'] == row['Logistic Regression']:
        counter += 1
    counts.append(counter)
model_matrix_p['Number Correct'] = counts
model_matrix_p
# Out:
# 1.0
# 1.0
# 0.7776315789473683
# 0.9966614452798663
# 1.0
#                           Actual  Random Forest  Support Vector Machine  \
# refinebio_accession_code
# SRR7725775                     0              0                       0
# SRR7725785                     0              0                       0
# SRR7725983                     1              1                       1
# SRR7725993                     0              0                       0
# SRR7726021                     1              1                       1
# SRR7725801                     0              0                       0
# SRR7725828                     1              1                       1
# SRR7726007                     1              1                       1
# SRR7725783                     1              1                       1
# SRR7726014                     1              1                       1
# SRR7725777                     1              1                       1
# ...

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train['KMeans Cluster'])
rf_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMeans Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

clf = svm.SVC(kernel='linear', probability=True, random_state=20)
clf.fit(X_train, y_train['KMeans Cluster'])
svm_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMeans Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

nb = GaussianNB()
nb.fit(X_train, y_train['KMeans Cluster'])
nb_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMeans Cluster'], y_pred_prob, multi_class = 'ovr')
print(roc_auc)

knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train['KMeans Cluster'])
knn_pred = knn.predict(X_test)
y_pred_prob = knn.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMeans Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train['KMeans Cluster'])
lr_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(X_test)
roc_auc = metrics.roc_auc_score(y_test['KMeans Cluster'],  y_pred_prob, multi_class = 'ovr')
print(roc_auc)

model_matrix_k = pd.DataFrame({'Actual': y_test['KMeans Cluster'],
                            'Random Forest': rf_pred, 'Support Vector Machine': svm_pred,
                             'Naive Bayes': nb_pred, 'K-Nearest Neighbors': knn_pred,
                             'Logistic Regression': lr_pred})

counts = []
for row_name in model_matrix_k.index:
    row = model_matrix_k.loc[row_name]
    counter = 0
    if row['Actual'] == row['Random Forest']:
        counter += 1
    if row['Actual'] == row['Support Vector Machine']:
        counter += 1
    if row['Actual'] == row['Naive Bayes']:
        counter += 1
    if row['Actual'] == row['K-Nearest Neighbors']:
        counter += 1
    if row['Actual'] == row['Logistic Regression']:
        counter += 1
    counts.append(counter)
model_matrix_k['Number Correct'] = counts
model_matrix_k
# Out:
# 0.9961380073779267
# 1.0
# 0.6649167364893172
# 0.9898213849322721
# 0.99921875
#                           Actual  Random Forest  Support Vector Machine  \
# refinebio_accession_code
# SRR7725775                     3              3                       3
# SRR7725785                     4              1                       4
# SRR7725983                     4              4                       4
# SRR7725993                     3              3                       3
# SRR7726021                     0              0                       0
# SRR7725801                     1              1                       1
# SRR7725828                     0              0                       0
# SRR7726007                     0              0                       0
# SRR7725783                     0              0                       0
# SRR7726014                     0              0                       0
# SRR7725777                     0              0                       0
# ...

# %%
wut = pd.concat([model_matrix_group, model_matrix_a, model_matrix_s, model_matrix_g, model_matrix_p, model_matrix_k], axis=1)

# %%
wut
# Out:
#                                     Actual     Random Forest  \
# refinebio_accession_code
# SRR7725775                         healthy           healthy
# SRR7725785                         healthy           healthy
# SRR7725983                ra non treatment  ra non treatment
# SRR7725993                ra non treatment           healthy
# SRR7726021                ra non treatment  ra non treatment
# SRR7725801                         healthy           healthy
# SRR7725828                         healthy  ra non treatment
# SRR7726007                ra non treatment  ra non treatment
# SRR7725783                         healthy  ra non treatment
# SRR7726014                ra non treatment  ra non treatment
# SRR7725777                         healthy  ra non treatment
# SRR7726000                ra non treatment           healthy
# SRR7725969                ra non treatment           healthy
# SRR7726005                ra non treatment           healthy
# ...

# %%
wut.columns = pd.MultiIndex.from_product([['Group', 'Agglomerative', 'Spectral', 'GMM', 'KMedoids', 'KMeans'], model_matrix_a.columns])

# %%
wut.to_csv('Compiled Model Results.csv')

# %%
wut = pd.read_csv('Compiled Model Results.csv', index_col=0, header=[0, 1])

# %%
wut
# Out:
#                                      Group                    \
#                                     Actual     Random Forest
# refinebio_accession_code
# SRR7725775                         healthy           healthy
# SRR7725785                         healthy           healthy
# SRR7725983                ra non treatment  ra non treatment
# SRR7725993                ra non treatment           healthy
# SRR7726021                ra non treatment  ra non treatment
# SRR7725801                         healthy           healthy
# SRR7725828                         healthy  ra non treatment
# SRR7726007                ra non treatment  ra non treatment
# SRR7725783                         healthy  ra non treatment
# SRR7726014                ra non treatment  ra non treatment
# SRR7725777                         healthy  ra non treatment
# SRR7726000                ra non treatment           healthy
# SRR7725969                ra non treatment           healthy
# ...

# %%
plt.figure(figsize=(12,10))
plt.subplot(2, 3, 1)
plt.hist(wut['Group']['Number Correct'])
plt.title('Group Histogram')
plt.xlabel('Number Correct')
plt.ylabel('Frequency')
plt.subplot(2, 3, 2)
plt.hist(wut['Agglomerative']['Number Correct'])
plt.title('Hierarchical Clustering Histogram')
plt.xlabel('Number Correct')
plt.ylabel('Frequency')
plt.subplot(2, 3, 3)
plt.hist(wut['Spectral']['Number Correct'])
plt.title('Spectral Clustering Histogram')
plt.xlabel('Number Correct')
plt.ylabel('Frequency')
plt.subplot(2, 3, 4)
plt.hist(wut['GMM']['Number Correct'])
plt.title('Gaussian Mixture Model Histogram')
plt.xlabel('Number Correct')
plt.ylabel('Frequency')
plt.subplot(2, 3, 5)
plt.hist(wut['KMedoids']['Number Correct'])
plt.title('PAM Clustering Histogram')
plt.xlabel('Number Correct')
plt.ylabel('Frequency')
plt.subplot(2, 3, 6)
plt.hist(wut['KMeans']['Number Correct'])
plt.title('KMeans Clustering Histogram')
plt.xlabel('Number Correct')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Statistical Tests

# %%
from scipy import stats

# %%
#Each Pearson Correlation Test Between Labels and Clusters
print(stats.pearsonr(wut['Group']['Number Correct'], wut['Agglomerative']['Number Correct']))
print(stats.pearsonr(wut['Group']['Number Correct'], wut['Spectral']['Number Correct']))
print(stats.pearsonr(wut['Group']['Number Correct'], wut['GMM']['Number Correct']))
print(stats.pearsonr(wut['Group']['Number Correct'], wut['KMedoids']['Number Correct']))
print(stats.pearsonr(wut['Group']['Number Correct'], wut['KMeans']['Number Correct']))
# Out:
# PearsonRResult(statistic=0.28548379537327107, pvalue=0.07415228947891944)
# PearsonRResult(statistic=0.1343200139256736, pvalue=0.408616613537772)
# PearsonRResult(statistic=0.10619718731192974, pvalue=0.5142720127972606)
# PearsonRResult(statistic=0.3223904457257091, pvalue=0.04247364355600514)
# PearsonRResult(statistic=0.16543160584076702, pvalue=0.30765518499925715)

# %%
from statsmodels.stats.multitest import multipletests

# %%
adjusted_results = multipletests([0.0741522, 0.4086166, 0.51427201, 0.04247364,
                                  0.307655185], alpha=0.05, method='hs')

# %%
print('Adjusted p-values')
print(adjusted_results[1])
# Out:
# Adjusted p-values
# [0.26521819 0.66813051 0.66813051 0.19507819 0.66813051]

# %% [markdown]
# # HeatMap Generation

# %%
#Remapping Labels To Colors
lut = {'healthy': 'green', 'ra non treatment': 'purple'}
wut2 = wut['Group'].copy()
for column in wut['Group'].columns:
    wut2[column] = wut['Group'][column].map(lut)

# %%
wut2.drop('Number Correct', axis=1)
# Out:
#                           Actual Random Forest Support Vector Machine  \
# refinebio_accession_code
# SRR7725775                 green         green                  green
# SRR7725785                 green         green                  green
# SRR7725983                purple        purple                 purple
# SRR7725993                purple         green                 purple
# SRR7726021                purple        purple                 purple
# SRR7725801                 green         green                  green
# SRR7725828                 green        purple                 purple
# SRR7726007                purple        purple                 purple
# SRR7725783                 green        purple                 purple
# SRR7726014                purple        purple                 purple
# SRR7725777                 green        purple                  green
# SRR7726000                purple         green                 purple
# ...

# %%
clf = RandomForestClassifier(max_depth = 2,random_state=0)
clf.fit(X_train, y_train['Group'])
rf_pred = clf.predict(df_5000)

clf = svm.SVC(kernel='linear', probability=True, random_state=20)
clf.fit(X_train, y_train['Group'])
svm_pred = clf.predict(df_5000)

nb = GaussianNB()
nb.fit(X_train, y_train['Group'])
nb_pred = nb.predict(df_5000)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train['Group'])
knn_pred = knn.predict(df_5000)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train['Group'])
lr_pred = lr.predict(df_5000)

# %%
model_matrix_group = pd.DataFrame({'Actual': labels['Group'],
                            'Random Forest': rf_pred, 'Support Vector Machine': svm_pred,
                             'Naive Bayes': nb_pred, 'K-Nearest Neighbors': knn_pred,
                             'Logistic Regression': lr_pred})

# %%
#Remapping Labels To Colors
lut = {'healthy': 'green', 'ra non treatment': 'purple'}
model_matrix_group2 = model_matrix_group.copy()
for column in model_matrix_group.columns:
    model_matrix_group2[column] = model_matrix_group[column].map(lut)

# %%
model_matrix_group2
# Out:
#                           Actual Random Forest Support Vector Machine  \
# refinebio_accession_code
# SRR7725764                 green         green                  green
# SRR7725765                 green         green                  green
# SRR7725767                 green         green                  green
# SRR7725768                 green         green                  green
# SRR7725770                 green         green                  green
# ...                          ...           ...                    ...
# SRR7726017                purple        purple                 purple
# SRR7726018                purple        purple                 purple
# SRR7726019                purple        purple                 purple
# SRR7726020                purple        purple                 purple
# SRR7726021                purple        purple                 purple
#
#                          Naive Bayes K-Nearest Neighbors Logistic Regression
# ...

# %%
import seaborn as sns

# %%
df.columns.name = 'Gene'
df.index.name = 'Sample'

# %%
# Use seaborn to create the heatmap
sns.clustermap(df.iloc[:, :5000], row_colors=model_matrix_group2, cmap="coolwarm",
               figsize=(16, 10), dendrogram_ratio=(0.05, 0.2), colors_ratio=(0.01, 0.2),
               cbar_pos=(0.02, 0.85, 0.02, 0.14))

# Show the heatmap
plt.savefig('assignment4_heatmap.png')
plt.show()
# Out:
# C:\Users\13523\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# C:\Users\13523\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
